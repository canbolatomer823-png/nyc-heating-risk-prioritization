# %% [markdown]
# # Exploration Template
# Document the questions you want to answer with the dataset. Keep notes on data quality issues you observe so you can fix them in Glue later.

# %%
import pandas as pd

sample_path = '../data/sample.csv'
df = pd.read_csv(sample_path)
df.head()

# %%
df.describe(include='all')
